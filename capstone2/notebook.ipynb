# %% [markdown]
# ## About Dataset

# %% [markdown]
# ### Overview
#
# This dataset provides a comprehensive view of customer purchasing behavior and sales insights, tailored for analysis and modeling in the retail and e-commerce sectors. It contains diverse features, including customer demographics, purchasing patterns, product details, and retention strategies. The dataset is ideal for `exploratory data analysis (EDA)`, `predictive modeling`, and developing `customer segmentation` or `churn prediction models`.

# %% [markdown]
# **Features**
#
# * Customer Details: Unique customer IDs and their purchase-related attributes.
# * Product Information: Product IDs and frequently purchased categories.
# * Sales Metrics: Average order value, lifetime value, and purchase frequency.
# * Behavioral Insights: Time between purchases, preferred purchase times, and most frequent categories.
# * Geographical Insights: Regions such as North America, Europe, Asia, and South America.
# * Seasonality: Peak sales dates and associated seasons.
# * Retention Strategies: Insights into applied customer retention methods like discounts, loyalty programs, and email campaigns.
# * Probability Metrics: Churn probability to measure customer attrition risk.

# %% [markdown]
# > **Applications**
# This dataset is suitable for various analytical and machine learning tasks, including:
#
# * Customer segmentation and clustering.
# * Churn prediction modeling.
# * Analyzing seasonal and regional sales trends.
# * Evaluating retention strategies.
# * Identifying patterns in purchasing behaviors.

# %% [markdown]
# > **Format**
# The dataset is provided in CSV format, containing 10,000 rows and 15 columns. Each row represents a unique transaction or customer insight.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\pc\Downloads\sales_and_customer_insights.csv")
df.head()
# Out:
#    Customer_ID   Product_ID Transaction_ID  Purchase_Frequency  \
# 0  CUST_9HOS83  PROD_IK97D1   TRANS_II1DZG                  17
# 1  CUST_AJU17N  PROD_UNN7KP   TRANS_9HJF7I                  10
# 2  CUST_11XNYF  PROD_0XEW2W   TRANS_OT96OM                   3
# 3  CUST_IGH8G3  PROD_3IIAJN   TRANS_45V00G                  12
# 4  CUST_OK6PUM  PROD_VMIWD2   TRANS_ZAK760                  18
#
#    Average_Order_Value Most_Frequent_Category  Time_Between_Purchases  \
# 0               172.57            Electronics                      45
# 1                64.89               Clothing                       6
# 2               120.38                 Sports                      23
# 3                70.34               Clothing                       5
# 4                42.39            Electronics                      10
#
#           Region  Churn_Probability  Lifetime_Value Launch_Date  \
# 0  South America               0.98          952.81  2020-03-14
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer_ID               10000 non-null  object
#  1   Product_ID                10000 non-null  object
#  2   Transaction_ID            10000 non-null  object
#  3   Purchase_Frequency        10000 non-null  int64
#  4   Average_Order_Value       10000 non-null  float64
#  5   Most_Frequent_Category    10000 non-null  object
#  6   Time_Between_Purchases    10000 non-null  int64
#  7   Region                    10000 non-null  object
#  8   Churn_Probability         10000 non-null  float64
#  9   Lifetime_Value            10000 non-null  float64
#  10  Launch_Date               10000 non-null  object
#  11  Peak_Sales_Date           10000 non-null  object
#  12  Season                    10000 non-null  object
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Data Cleaning & Manipulation¶

# %%
# converting Launch_Date and Peak_Sales_Date columns into proper datetime objects using pandas.to_datetime. 

df['Launch_Date'] = pd.to_datetime(df['Launch_Date'])
df['Peak_Sales_Date'] = pd.to_datetime(df['Peak_Sales_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer_ID               10000 non-null  object
#  1   Product_ID                10000 non-null  object
#  2   Transaction_ID            10000 non-null  object
#  3   Purchase_Frequency        10000 non-null  int64
#  4   Average_Order_Value       10000 non-null  float64
#  5   Most_Frequent_Category    10000 non-null  object
#  6   Time_Between_Purchases    10000 non-null  int64
#  7   Region                    10000 non-null  object
#  8   Churn_Probability         10000 non-null  float64
#  9   Lifetime_Value            10000 non-null  float64
#  10  Launch_Date               10000 non-null  datetime64[ns]
#  11  Peak_Sales_Date           10000 non-null  datetime64[ns]
#  12  Season                    10000 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Customer_ID                 0
# Product_ID                  0
# Transaction_ID              0
# Purchase_Frequency          0
# Average_Order_Value         0
# Most_Frequent_Category      0
# Time_Between_Purchases      0
# Region                      0
# Churn_Probability           0
# Lifetime_Value              0
# Launch_Date                 0
# Peak_Sales_Date             0
# Season                      0
# Preferred_Purchase_Times    0
# Retention_Strategy          0
# dtype: int64

# %%
df
# Out:
#       Customer_ID   Product_ID Transaction_ID  Purchase_Frequency  \
# 0     CUST_9HOS83  PROD_IK97D1   TRANS_II1DZG                  17
# 1     CUST_AJU17N  PROD_UNN7KP   TRANS_9HJF7I                  10
# 2     CUST_11XNYF  PROD_0XEW2W   TRANS_OT96OM                   3
# 3     CUST_IGH8G3  PROD_3IIAJN   TRANS_45V00G                  12
# 4     CUST_OK6PUM  PROD_VMIWD2   TRANS_ZAK760                  18
# ...           ...          ...            ...                 ...
# 9995  CUST_BIH0QW  PROD_AAPCHD   TRANS_EP2EGL                  15
# 9996  CUST_DWJAD2  PROD_XWJQE5   TRANS_X7OPB7                  18
# 9997  CUST_43HBYL  PROD_PL3BU5   TRANS_VSZM3Y                  15
# 9998  CUST_0SX4MD  PROD_X5O49V   TRANS_B2YCHY                  12
# 9999  CUST_U1AP5I  PROD_CTS1GQ   TRANS_IBPVC5                   3
#
#       Average_Order_Value Most_Frequent_Category  Time_Between_Purchases  \
# 0                  172.57            Electronics                      45
# ...

# %%
import numpy as np

df.loc[0, 'Purchase_Frequency'] = np.nan

# %%
df
# Out:
#       Customer_ID   Product_ID Transaction_ID  Purchase_Frequency  \
# 0     CUST_9HOS83  PROD_IK97D1   TRANS_II1DZG                 NaN
# 1     CUST_AJU17N  PROD_UNN7KP   TRANS_9HJF7I                10.0
# 2     CUST_11XNYF  PROD_0XEW2W   TRANS_OT96OM                 3.0
# 3     CUST_IGH8G3  PROD_3IIAJN   TRANS_45V00G                12.0
# 4     CUST_OK6PUM  PROD_VMIWD2   TRANS_ZAK760                18.0
# ...           ...          ...            ...                 ...
# 9995  CUST_BIH0QW  PROD_AAPCHD   TRANS_EP2EGL                15.0
# 9996  CUST_DWJAD2  PROD_XWJQE5   TRANS_X7OPB7                18.0
# 9997  CUST_43HBYL  PROD_PL3BU5   TRANS_VSZM3Y                15.0
# 9998  CUST_0SX4MD  PROD_X5O49V   TRANS_B2YCHY                12.0
# 9999  CUST_U1AP5I  PROD_CTS1GQ   TRANS_IBPVC5                 3.0
#
#       Average_Order_Value Most_Frequent_Category  Time_Between_Purchases  \
# 0                  172.57            Electronics                      45
# ...

# %%
df.isna().sum()
# Out:
# Customer_ID                 0
# Product_ID                  0
# Transaction_ID              0
# Purchase_Frequency          1
# Average_Order_Value         0
# Most_Frequent_Category      0
# Time_Between_Purchases      0
# Region                      0
# Churn_Probability           0
# Lifetime_Value              0
# Launch_Date                 0
# Peak_Sales_Date             0
# Season                      0
# Preferred_Purchase_Times    0
# Retention_Strategy          0
# dtype: int64

# %%
mean_value = df['Purchase_Frequency'].mean()
rounded_mean = round(mean_value)

rounded_mean
# Out:
# 10

# %%
df['Purchase_Frequency'] = df['Purchase_Frequency'].fillna(rounded_mean)

df
# Out:
#       Customer_ID   Product_ID Transaction_ID  Purchase_Frequency  \
# 0     CUST_9HOS83  PROD_IK97D1   TRANS_II1DZG                10.0
# 1     CUST_AJU17N  PROD_UNN7KP   TRANS_9HJF7I                10.0
# 2     CUST_11XNYF  PROD_0XEW2W   TRANS_OT96OM                 3.0
# 3     CUST_IGH8G3  PROD_3IIAJN   TRANS_45V00G                12.0
# 4     CUST_OK6PUM  PROD_VMIWD2   TRANS_ZAK760                18.0
# ...           ...          ...            ...                 ...
# 9995  CUST_BIH0QW  PROD_AAPCHD   TRANS_EP2EGL                15.0
# 9996  CUST_DWJAD2  PROD_XWJQE5   TRANS_X7OPB7                18.0
# 9997  CUST_43HBYL  PROD_PL3BU5   TRANS_VSZM3Y                15.0
# 9998  CUST_0SX4MD  PROD_X5O49V   TRANS_B2YCHY                12.0
# 9999  CUST_U1AP5I  PROD_CTS1GQ   TRANS_IBPVC5                 3.0
#
#       Average_Order_Value Most_Frequent_Category  Time_Between_Purchases  \
# 0                  172.57            Electronics                      45
# ...

# %%
df = df.drop(["Customer_ID", "Product_ID","Transaction_ID"], axis= 1)

df
# Out:
#       Purchase_Frequency  Average_Order_Value Most_Frequent_Category  \
# 0                   10.0               172.57            Electronics
# 1                   10.0                64.89               Clothing
# 2                    3.0               120.38                 Sports
# 3                   12.0                70.34               Clothing
# 4                   18.0                42.39            Electronics
# ...                  ...                  ...                    ...
# 9995                15.0               162.51               Clothing
# 9996                18.0                63.02               Clothing
# 9997                15.0               116.80                   Home
# 9998                12.0               144.21            Electronics
# 9999                 3.0                91.32            Electronics
#
#       Time_Between_Purchases         Region  Churn_Probability  \
# 0                         45  South America               0.98
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Purchase_Frequency  Average_Order_Value Most_Frequent_Category  \
# 0                   10.0               172.57            Electronics
# 1                   10.0                64.89               Clothing
# 2                    3.0               120.38                 Sports
# 3                   12.0                70.34               Clothing
# 4                   18.0                42.39            Electronics
# ...                  ...                  ...                    ...
# 9995                15.0               162.51               Clothing
# 9996                18.0                63.02               Clothing
# 9997                15.0               116.80                   Home
# 9998                12.0               144.21            Electronics
# 9999                 3.0                91.32            Electronics
#
#       Time_Between_Purchases         Region  Churn_Probability  \
# ...

# %% [markdown]
# ### Correlation Analysis¶
#
# Let's examine the correlation between **numeric features** to identify any **strong relationships**.

# %%
# Select numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Compute correlation matrix
corr_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Data Visualization¶

# %%
df
# Out:
#       Purchase_Frequency  Average_Order_Value Most_Frequent_Category  \
# 0                   10.0               172.57            Electronics
# 1                   10.0                64.89               Clothing
# 2                    3.0               120.38                 Sports
# 3                   12.0                70.34               Clothing
# 4                   18.0                42.39            Electronics
# ...                  ...                  ...                    ...
# 9995                15.0               162.51               Clothing
# 9996                18.0                63.02               Clothing
# 9997                15.0               116.80                   Home
# 9998                12.0               144.21            Electronics
# 9999                 3.0                91.32            Electronics
#
#       Time_Between_Purchases         Region  Churn_Probability  \
# 0                         45  South America               0.98
# ...

# %%
sns.countplot(data=df,x='Region')
plt.show()

# %%
v_c = df['Retention_Strategy'].value_counts()
v_c
# Out:
# Retention_Strategy
# Loyalty Program    3364
# Email Campaign     3359
# Discount           3277
# Name: count, dtype: int64

# %%
v_c_r = df['Region'].value_counts()
v_c_r
# Out:
# Region
# Europe           2547
# South America    2527
# Asia             2472
# North America    2454
# Name: count, dtype: int64

# %%
# !pip install plotly

# %%
# Import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Set visual style
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# --- 1. Distribution of Numerical Features ---

# Plot distribution of Average_Order_Value
plt.figure(figsize=(10, 6))
sns.histplot(df['Average_Order_Value'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Average Order Value')
plt.xlabel('Average Order Value (USD)')
plt.ylabel('Frequency')
plt.show()

# Plot distribution of Lifetime_Value
plt.figure(figsize=(10, 6))
sns.histplot(df['Lifetime_Value'], bins=30, kde=True, color='orange')
plt.title('Distribution of Customer Lifetime Value')
plt.xlabel('Lifetime Value (USD)')
plt.ylabel('Frequency')
plt.show()

# Plot distribution of Churn_Probability
plt.figure(figsize=(10, 6))
sns.histplot(df['Churn_Probability'], bins=30, kde=True, color='green')
plt.title('Distribution of Churn Probability')
plt.xlabel('Churn Probability')
plt.ylabel('Frequency')
plt.show()

# --- 2. Visualize Categorical Feature Distributions ---

# Plot count of customers by Region
plt.figure(figsize=(10, 6))
sns.countplot(x='Region', data=df, palette='viridis')
plt.title('Customer Count by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()

# Plot count of Most Frequent Category
plt.figure(figsize=(10, 6))
sns.countplot(x='Most_Frequent_Category', data=df, palette='muted')
plt.title('Customer Count by Most Frequent Category')
plt.xlabel('Most Frequent Category')
plt.ylabel('Count')
plt.show()

# --- 3. Correlation Heatmap for Numerical Features ---

# Calculate correlation matrix
correlation_matrix = df[['Purchase_Frequency', 'Average_Order_Value', 
                         'Time_Between_Purchases', 'Churn_Probability', 'Lifetime_Value']].corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
import plotly.io as pio
pio.renderers.default = 'iframe'

# Distribution of Purchase Frequency
plt.figure(figsize=(8, 6))
sns.histplot(df['Purchase_Frequency'], bins=30, kde=True)
plt.title('Distribution of Purchase Frequency')
plt.xlabel('Purchase Frequency')
plt.ylabel('Count')
plt.show()

# %%
fig = px.bar(x = v_c.index, y = v_c.values, color=v_c.index)
fig.update_layout(xaxis_title = "Promotion Type", yaxis_title = "Count", title = "Promotion Types by Count")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df['Sales'] = df['Purchase_Frequency'] * df['Average_Order_Value']
df.head()
# Out:
#    Purchase_Frequency  Average_Order_Value Most_Frequent_Category  \
# 0                10.0               172.57            Electronics
# 1                10.0                64.89               Clothing
# 2                 3.0               120.38                 Sports
# 3                12.0                70.34               Clothing
# 4                18.0                42.39            Electronics
#
#    Time_Between_Purchases         Region  Churn_Probability  Lifetime_Value  \
# 0                      45  South America               0.98          952.81
# 1                       6  South America               0.66         5427.51
# 2                      23           Asia               0.60         3994.80
# 3                       5  North America               0.78         4880.01
# 4                      10  North America               0.52         8557.70
#
#   Launch_Date Peak_Sales_Date  Season Preferred_Purchase_Times  \
# ...

# %%
royal = df.groupby('Retention_Strategy')['Sales'].sum().sort_values(ascending = False)
royal_df = royal.rename_axis('Most_Frequent_Category').reset_index()
print(royal_df)
# Out:
#   Most_Frequent_Category       Sales
# 0         Email Campaign  3691445.03
# 1        Loyalty Program  3684934.54
# 2               Discount  3574073.66

# %%
print(df['Peak_Sales_Date'].dtype)
# Out:
# datetime64[ns]

# %%
# Extract numeric month (1–12)
df['Month'] = df['Peak_Sales_Date'].dt.month

df.head(3)
# Out:
#    Purchase_Frequency  Average_Order_Value Most_Frequent_Category  \
# 0                10.0               172.57            Electronics
# 1                10.0                64.89               Clothing
# 2                 3.0               120.38                 Sports
#
#    Time_Between_Purchases         Region  Churn_Probability  Lifetime_Value  \
# 0                      45  South America               0.98          952.81
# 1                       6  South America               0.66         5427.51
# 2                      23           Asia               0.60         3994.80
#
#   Launch_Date Peak_Sales_Date  Season Preferred_Purchase_Times  \
# 0  2020-03-14      2023-09-11  Winter                Afternoon
# 1  2022-10-15      2023-01-02  Spring                Afternoon
# 2  2021-11-30      2023-04-06  Winter                  Evening
#
#   Retention_Strategy    Sales  Month
# 0    Loyalty Program  1725.70      9
# 1           Discount   648.90      1
# ...

# %%
results = df.groupby('Month').sum(numeric_only=True)

results
# Out:
#        Purchase_Frequency  Average_Order_Value  Time_Between_Purchases  \
# Month
# 1                  8740.0             96458.57                   41185
# 2                  7561.0             84768.60                   36908
# 3                  8405.0             91372.63                   38400
# 4                  8009.0             88598.88                   37648
# 5                  8392.0             96351.39                   41753
# 6                  7849.0             88437.58                   36290
# 7                  8507.0             94434.11                   40719
# 8                  8122.0             91878.46                   39186
# 9                  8370.0             91054.46                   38256
# 10                 8754.0             93258.65                   40535
# 11                 8307.0             88807.87                   37498
# 12                 8534.0             94639.02                   40475
#
# ...

# %%
months = range(1, 13)

plt.figure(figsize=(10, 6))
sns.barplot(x=list(months), y=results['Sales'], palette="tab10")  # or "Set3", "husl", etc.
plt.xticks(months)
plt.ylabel('Sales $')
plt.xlabel('Months')
plt.show()

# %%
sns.countplot(data=df,x='Season')
plt.ylabel('Sales $') 
plt.xlabel('Season') 
plt.show()

# %%
category = df.groupby('Most_Frequent_Category')['Sales'].sum().sort_values(ascending = False)
category_df = category.rename_axis('Most_Frequent_Category').reset_index()
print(category_df)
# Out:
#   Most_Frequent_Category       Sales
# 0            Electronics  2819168.43
# 1               Clothing  2747636.65
# 2                   Home  2715868.56
# 3                 Sports  2667779.59

# %%
plt.figure(figsize=(8, 8))
plt.pie(category, labels=category.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen', 'coral', 'orchid'])
plt.title('Most Frequent Category')
plt.show()
