# %% [markdown]
# ## Homework
#
# > **Note**: it's very likely that in this homework your answers won't match
# > the options exactly. That's okay and expected. Select the option that's
# > closest to your solution.
# > If it's exactly in between two options, select the higher value.

# %% [markdown]
# ## Hair Type Dataset

# %% [markdown]
# ### Dataset
#
# In this homework, we'll build a model for classifying various hair types.
# For this, we will use the Hair Type dataset that was obtained from
# [Kaggle](https://www.kaggle.com/datasets/kavyasreeb/hair-type-dataset)
# and slightly rebuilt.

# %% [markdown]
# You can download the target dataset for this homework from
# [here](https://github.com/SVizor42/ML_Zoomcamp/releases/download/straight-curly-data/data.zip):

# %% [markdown]
# ```bash
# wget https://github.com/SVizor42/ML_Zoomcamp/releases/download/straight-curly-data/data.zip
# unzip data.zip
# ```

# %% [markdown]
# In the lectures we saw how to use a pre-trained neural network. In the homework, we'll train a much smaller model from scratch.
#
# We will use PyTorch for that.
#
# You can use Google Colab or your own computer for that.

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# The dataset contains around 1000 images of hairs in the separate folders
# for training and test sets.

# %%
df_url = "https://github.com/SVizor42/ML_Zoomcamp/releases/download/straight-curly-data/data.zip"

# %% [markdown]
# ### Reproducibility

# %% [markdown]
# Reproducibility in deep learning is a multifaceted challenge that requires attention
# to both software and hardware details. In some cases, we can't guarantee exactly the same results during the same experiment runs.

# %% [markdown]
# Therefore, in this homework we suggest to set the random number seed generators by:
#
# ```python
# import numpy as np
# import torch
#
# SEED = 42
# np.random.seed(SEED)
# torch.manual_seed(SEED)
#
# if torch.cuda.is_available():
#     torch.cuda.manual_seed(SEED)
#     torch.cuda.manual_seed_all(SEED)
#
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False
# ```

# %% [markdown]
# Also, use PyTorch of version 2.8.0 (that's the one in Colab).

# %% [markdown]
# ### Model

# %% [markdown]
# For this homework we will use Convolutional Neural Network (CNN). We'll use PyTorch.
#
# You need to develop the model with following structure:
#
# * The shape for input should be `(3, 200, 200)` (channels first format in PyTorch)
# * Next, create a convolutional layer (`nn.Conv2d`):
#     * Use 32 filters (output channels)
#     * Kernel size should be `(3, 3)` (that's the size of the filter), padding = 0, stride = 1
#     * Use `'relu'` as activation
# * Reduce the size of the feature map with max pooling (`nn.MaxPool2d`)
#     * Set the pooling size to `(2, 2)`
# * Turn the multi-dimensional result into vectors using `flatten` or `view`
# * Next, add a `nn.Linear` layer with 64 neurons and `'relu'` activation
# * Finally, create the `nn.Linear` layer with 1 neuron - this will be the output
#     * The output layer should have an activation - use the appropriate activation for the binary classification case
#
# As optimizer use `torch.optim.SGD` with the following parameters:
#
# * `torch.optim.SGD(model.parameters(), lr=0.002, momentum=0.8)`

# %% [markdown]
# ### Question 1
#
# Which loss function you will use?
#
# * `nn.MSELoss()`
# * `nn.BCEWithLogitsLoss()`
# * `nn.CrossEntropyLoss()`
# * `nn.CosineEmbeddingLoss()`
#
# (Multiple answered can be correct, so pick any)

# %% [markdown]
# #### Imports

# %%
# !pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2
#    -------------------- ------------------ 58.2/111.0 MB 161.6 kB/s eta 0:05:27
#    -------------------- ------------------ 58.2/111.0 MB 161.6 kB/s eta 0:05:27
#    -------------------- ------------------ 58.2/111.0 MB 161.6 kB/s eta 0:05:27
#    -------------------- ------------------ 58.5/111.0 MB 165.4 kB/s eta 0:05:18
#    -------------------- ------------------ 58.5/111.0 MB 165.4 kB/s eta 0:05:18
#    -------------------- ------------------ 58.7/111.0 MB 172.4 kB/s eta 0:05:04
#    -------------------- ------------------ 58.7/111.0 MB 172.4 kB/s eta 0:05:04
#    -------------------- ------------------ 59.0/111.0 MB 178.6 kB/s eta 0:04:52
#    -------------------- ------------------ 59.0/111.0 MB 178.6 kB/s eta 0:04:52
#    -------------------- ------------------ 59.0/111.0 MB 178.6 kB/s eta 0:04:52
#    -------------------- ------------------ 59.2/111.0 MB 184.4 kB/s eta 0:04:41
#    -------------------- ------------------ 59.2/111.0 MB 184.4 kB/s eta 0:04:41
#    -------------------- ------------------ 59.5/111.0 MB 188.1 kB/s eta 0:04:34
#    -------------------- ------------------ 59.5/111.0 MB 188.1 kB/s eta 0:04:34
#    -------------------- ------------------ 59.5/111.0 MB 188.1 kB/s eta 0:04:34
#    --------------------- ----------------- 59.8/111.0 MB 194.1 kB/s eta 0:04:24
#    --------------------- ----------------- 59.8/111.0 MB 194.1 kB/s eta 0:04:24
#    --------------------- ----------------- 59.8/111.0 MB 194.1 kB/s eta 0:04:24
#    --------------------- ----------------- 59.8/111.0 MB 194.1 kB/s eta 0:04:24
# ...
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    -------------------- ------------------- 4/8 [filelock]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ---------------------------------------- 8/8 [torchaudio]
#
# Successfully installed filelock-3.20.0 fsspec-2025.10.0 mpmath-1.3.0 networkx-3.6 sympy-1.14.0 torch-2.9.1 torchaudio-2.9.1 torchvision-0.24.1

# %%
import os
import torch
import torch.nn as nn
from torchvision import transforms
from PIL import Image

# %%
import numpy as np
import torch

SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# #### Directory

# %%
data_dir = "../dataa"
data_dir
# Out:
# '../dataa'

# %%
train_dir = os.path.join(data_dir, "train")
train_dir
# Out:
# '../dataa\\train'

# %%
test_dir = os.path.join(data_dir, "test")
test_dir
# Out:
# '../dataa\\test'

# %% [markdown]
# **The shape for input should be (3, 200, 200) (channels first format in PyTorch)**

# %%
train_transforms = transforms.Compose([
    transforms.Resize((200, 200)),
    transforms.ToTensor()
])

# %%
train_transforms
# Out:
# Compose(
#     Resize(size=(200, 200), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
# )

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\pc\lesson\machine-learning-zoomcamp-homework\08-deep-learning-and-nn

# %%
print(f"{train_dir}/curly/tp-sassy-short-curly-hairstyles-women.jpg")
# Out:
# ../data/HairType/data\train/curly/tp-sassy-short-curly-hairstyles-women.jpg

# %%
from PIL import Image

# Make sure the path is correct
img_path = r"C:\Users\pc\Downloads\data\data\train\curly\tp-sassy-short-curly-hairstyles-women.jpg"

# Open the image
img = Image.open(img_path)

# %%
# Show the image
img.show()

# Resize example
img_resized = img.resize((200, 200))
img_resized.show()

# %%
x = train_transforms(img)
x
# Out:
# tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.4745, 0.4745, 0.4745,  ..., 0.4471, 0.4471, 0.4471],
#          [0.4784, 0.4784, 0.4745,  ..., 0.4471, 0.4471, 0.4471],
#          [0.4784, 0.4784, 0.4784,  ..., 0.4471, 0.4471, 0.4471],
#          ...,
#          [0.6118, 0.6118, 0.6118,  ..., 0.4745, 0.4745, 0.4745],
#          [0.6078, 0.6118, 0.6118,  ..., 0.4745, 0.4745, 0.4745],
#          [0.6078, 0.6078, 0.6078,  ..., 0.4784, 0.4784, 0.4745]],
#
#         [[0.6196, 0.6196, 0.6196,  ..., 0.5922, 0.5922, 0.5922],
#          [0.6235, 0.6235, 0.6196,  ..., 0.5922, 0.5922, 0.5922],
#          [0.6235, 0.6235, 0.6235,  ..., 0.5922, 0.5922, 0.5922],
#          ...,
#          [0.7608, 0.7608, 0.7608,  ..., 0.6196, 0.6196, 0.6196],
#          [0.7569, 0.7608, 0.7608,  ..., 0.6196, 0.6196, 0.6196],
#          [0.7569, 0.7569, 0.7569,  ..., 0.6235, 0.6235, 0.6196]]])

# %%
x.shape
# Out:
# torch.Size([3, 200, 200])

# %%
test_transforms = transforms.Compose([
    transforms.Resize((200, 200)),
    transforms.ToTensor()
])

# %%
test_transforms
# Out:
# Compose(
#     Resize(size=(200, 200), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
# )

# %%
img = Image.open(f"{test_dir}/curly/6d8acb0fe980774ea4e5631198587f45.png")
img.resize((200, 200))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 img = Image.open(f"{test_dir}/curly/6d8acb0fe980774ea4e5631198587f45.png")
#       2 img.resize((200, 200))
#
# File ~\miniconda3\envs\machine-learning-zoomcamp-homework\Lib\site-packages\PIL\Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
#    3514     exclusive_fp = True
#    3515 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../dataa\\test/curly/6d8acb0fe980774ea4e5631198587f45.png'

# %%
# Make sure the path is correct
img_path = "machine-learning-zoomcamp-homework/08-deep-learning-and-nn/dataa/test/curly/grow-longer-curly-hair_750x500_6.jpg"

# Open the image
img = Image.open(img_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 5
#       2 img_path = "machine-learning-zoomcamp-homework/08-deep-learning-and-nn/dataa/test/curly/grow-longer-curly-hair_750x500_6.jpg"
#       4 # Open the image
# ----> 5 img = Image.open(img_path)
#
# File ~\miniconda3\envs\machine-learning-zoomcamp-homework\Lib\site-packages\PIL\Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
#    3514     exclusive_fp = True
#    3515 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'machine-learning-zoomcamp-homework/08-deep-learning-and-nn/dataa/test/curly/grow-longer-curly-hair_750x500_6.jpg'
