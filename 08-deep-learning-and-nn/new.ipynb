# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
# !python --version
# Out:
# Python 3.13.5

# %%
import tensorflow as tf

# %%
print(tf.reduce_sum(tf.random.normal([1000, 1000])))
# Out:
# tf.Tensor(-1652.2201, shape=(), dtype=float32)

# %%
print("Num GPUs Available : ", len(tf.config.list_physical_devices(('GPU'))))
# Out:
# Num GPUs Available :  0
