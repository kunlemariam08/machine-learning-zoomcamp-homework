# %%
import pandas as pd
import numpy as np

# %%
# Use raw strings (r"...") or double backslashes to avoid escape errors
df = pd.read_csv(r"C:\Users\pc\Downloads\train.csv")
df_test = pd.read_csv(r"C:\Users\pc\Downloads\test.csv")

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df_test
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
df.shape
# Out:
# (2000, 21)

# %% [markdown]
# ## Data Representation¶

# %%
df.head().T
# Out:
#                     0       1       2       3       4
# battery_power   842.0  1021.0   563.0   615.0  1821.0
# blue              0.0     1.0     1.0     1.0     1.0
# clock_speed       2.2     0.5     0.5     2.5     1.2
# dual_sim          0.0     1.0     1.0     0.0     0.0
# fc                1.0     0.0     2.0     0.0    13.0
# four_g            0.0     1.0     1.0     0.0     1.0
# int_memory        7.0    53.0    41.0    10.0    44.0
# m_dep             0.6     0.7     0.9     0.8     0.6
# mobile_wt       188.0   136.0   145.0   131.0   141.0
# n_cores           2.0     3.0     5.0     6.0     2.0
# pc                2.0     6.0     6.0     9.0    14.0
# px_height        20.0   905.0  1263.0  1216.0  1208.0
# px_width        756.0  1988.0  1716.0  1786.0  1212.0
# ram            2549.0  2631.0  2603.0  2769.0  1411.0
# sc_h              9.0    17.0    11.0    16.0     8.0
# sc_w              7.0     3.0     2.0     8.0     2.0
# ...

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# ## **The Features info**
#
# price_range:This indicates the mobile phone's price category {0 Very low price / 1 Average price / 2 High price / 3 Very high price}
#
# battery_power:Battery capacity in milliampere-hours (mAh)
#
# clock_speed:Processor speed in GHz (CPU)
#
# n_cores:Number of processor cores
#
# Ram:RAM size (MB)
#
# Camera:{fc-->Front camera resolution (megapixels) / pc-->Rear camera resolution}
#
# four_g:Does it support 4G?
#
# three_g:Does it support 3G?
#
# wifi:WiFi support
#
# blue:Bluetooth Support
#
# px_height:High screen pixel resolution
#
# px_width:width screen pixel resolution
#
# sc_h:Screen height (cm)
#
# sc_w:Screen width (cm)
#
# int_memory:Internal memory (GB)
#
# mobile_wt:Mobile phone weight (grams)
#
# m_dep:Mobile phone thickness (cm)
#
# dual_sim:Dual SIM support?
#
# touch_screen:Is the screen Touch?
#
# talk_time:Number of hours of calls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ## Data Analysis¶

# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
sns.scatterplot(df,x='price_range',y='battery_power')
plt.title("Distribution of battery_power / price_range")
plt.show()

# %%
sns.boxplot(df['price_range'])
plt.title("Boxplot Distribution of price_range")
plt.show()

# %%
df['price_range'].plot(kind='kde')
plt.title("KDE Distribution of price_range")
plt.show()

# %%
df.groupby('battery_power')['price_range'].mean().reset_index().sample(10)
# Out:
#       battery_power  price_range
# 15              518     1.500000
# 522            1208     1.000000
# 948            1812     3.000000
# 799            1602     1.500000
# 79              602     2.000000
# 1061           1960     3.000000
# 1089           1994     1.666667
# 614            1339     1.000000
# 868            1698     1.333333
# 168             722     1.000000

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df['blue'].value_counts().reset_index()
# Out:
#    blue  count
# 0     0   1010
# 1     1    990

# %% [markdown]
# There are more mobile phones that do not have **Bluetooth** technology than those that do.

# %%
sns.barplot(x=df['blue'] , y = df['price_range'])
# Out:
# <Axes: xlabel='blue', ylabel='price_range'>

# %% [markdown]
# we can see the prices of phones with bluetooth is slightly higher than phones without bluetooth

# %%
df['dual_sim'].value_counts().reset_index()
# Out:
#    dual_sim  count
# 0         1   1019
# 1         0    981

# %%
sns.barplot(x=df['dual_sim'] , y = df['price_range'])
# Out:
# <Axes: xlabel='dual_sim', ylabel='price_range'>

# %%
df.loc[:,['clock_speed','battery_power','int_memory','n_cores','ram','fc','pc','price_range']].corr()
# Out:
#                clock_speed  battery_power  int_memory   n_cores       ram  \
# clock_speed       1.000000       0.011482    0.006545 -0.005724  0.003443
# battery_power     0.011482       1.000000   -0.004004 -0.029727 -0.000653
# int_memory        0.006545      -0.004004    1.000000 -0.028310  0.032813
# n_cores          -0.005724      -0.029727   -0.028310  1.000000  0.004868
# ram               0.003443      -0.000653    0.032813  0.004868  1.000000
# fc               -0.000434       0.033334   -0.029133 -0.013356  0.015099
# pc               -0.005245       0.031441   -0.033273 -0.001193  0.028984
# price_range      -0.006606       0.200723    0.044435  0.004399  0.917046
#
#                      fc        pc  price_range
# clock_speed   -0.000434 -0.005245    -0.006606
# battery_power  0.033334  0.031441     0.200723
# int_memory    -0.029133 -0.033273     0.044435
# n_cores       -0.013356 -0.001193     0.004399
# ram            0.015099  0.028984     0.917046
# ...

# %%
corr_HW = df.loc[:,['clock_speed','battery_power','int_memory','n_cores','ram','fc','pc','price_range']].corr()
plt.figure(figsize=(12,6))
sns.heatmap(corr_HW ,annot=True)
plt.title('HardWare Correlations')
plt.show()

# %%
df.loc[:,['four_g','three_g','wifi','blue','price_range']].corr()
# Out:
#                four_g   three_g      wifi      blue  price_range
# four_g       1.000000  0.584246 -0.017620  0.013443     0.014772
# three_g      0.584246  1.000000  0.004316 -0.030236     0.023611
# wifi        -0.017620  0.004316  1.000000 -0.021863     0.018785
# blue         0.013443 -0.030236 -0.021863  1.000000     0.020573
# price_range  0.014772  0.023611  0.018785  0.020573     1.000000

# %%
corr_Net_con = df.loc[:,['four_g','three_g','wifi','blue','price_range']].corr()
plt.figure(figsize=(12,6))
sns.heatmap(corr_Net_con ,annot=True)
plt.title('Network & Connectivity Correlations')
plt.show()

# %%
corr_Phy = df.loc[:,['mobile_wt','m_dep','price_range']].corr()
plt.figure(figsize=(12,6))
sns.heatmap(corr_Phy ,annot=True)
plt.title('Physical Correlations')
plt.show()

# %%
corr_Dis_sto = df.loc[:,['px_height','px_width','sc_h','sc_w','int_memory','price_range']].corr()
plt.figure(figsize=(12,6))
sns.heatmap(corr_Dis_sto ,annot=True)
plt.title('Display & Storage Correlations')
plt.show()

# %% [markdown]
# The biggest hardware factor affecting a phone's price is **RAM**.
#
# The biggest factor affecting a phone's price is **network speed (3G)**.
#
# The biggest factor affecting a phone's price is **physical thickness**.
#
# The biggest factor affecting a phone's price is **display width (px)**.

# %% [markdown]
# ## Data Preprocessing¶

# %% [markdown]
# ### Data Splitting¶

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Prepare Features and Target¶
# We separate the dataset into:
#
# X: `Feature matrix` `(all columns except the target)` \
# y: `Target variable` `(price_range)`
#
#  This separation is essential for training our machine learning model.

# %%
x = df.drop('price_range',axis=1)
y = df['price_range']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,shuffle=True,random_state=42)

# %%
x_test
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1860           1646     0          2.5         0   3       1          25
# 353            1182     0          0.5         0   7       1           8
# 1333           1972     0          2.9         0   9       0          14
# 905             989     1          2.0         0   4       0          17
# 1289            615     1          0.5         1   7       0          58
# ...             ...   ...          ...       ...  ..     ...         ...
# 965            1379     0          0.5         1   1       0          19
# 1284            991     0          2.0         0   2       1          12
# 1739           1044     0          1.8         0   4       1          12
# 261             728     0          2.7         1   0       0          25
# 535            1185     0          1.9         0   0       0          31
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ### Data Scaling¶

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test  = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.91965677, -0.98142253,  1.20299532, ...,  0.55713671,
#          0.9900495 , -0.99750312],
#        [-0.13347738, -0.98142253, -1.23622976, ...,  0.55713671,
#         -1.0100505 , -0.99750312],
#        [ 1.65957429, -0.98142253,  1.69084034, ...,  0.55713671,
#          0.9900495 , -0.99750312],
#        ...,
#        [-0.446694  , -0.98142253,  0.34926654, ...,  0.55713671,
#          0.9900495 ,  1.00250313],
#        [-1.16391466, -0.98142253,  1.44691783, ...,  0.55713671,
#          0.9900495 ,  1.00250313],
#        [-0.12666832, -0.98142253,  0.4712278 , ...,  0.55713671,
#          0.9900495 ,  1.00250313]], shape=(400, 20))

# %% [markdown]
# ## Data Modeling¶

# %% [markdown]
# ### Logistic Regression¶

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(max_iter=2000)

lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
from sklearn.metrics import r2_score ,accuracy_score,confusion_matrix,classification_report

# %%
y_pre_train = lr.predict(x_train)
y_pre_test = lr.predict(x_test)

# %%
acc = accuracy_score(y_test , y_pre_test )
print(f'Accuracy = {acc}')
conf_ma = confusion_matrix(y_test,y_pre_test)
print(f"confusion matrix =\n {conf_ma}")
clas_rep = classification_report(y_test,y_pre_test)
print(f"Classification Report =\n {clas_rep}")
train_score = lr.score(x_train, y_train)
print(f"Train Score = {train_score}")
test_score = lr.score(x_test, y_test)
print(f"Test Score = {test_score}")
# Out:
# Accuracy = 0.975
# confusion matrix =
#  [[101   4   0   0]
#  [  0  91   0   0]
#  [  0   2  87   3]
#  [  0   0   1 111]]
# Classification Report =
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       105
#            1       0.94      1.00      0.97        91
#            2       0.99      0.95      0.97        92
#            3       0.97      0.99      0.98       112
#
#     accuracy                           0.97       400
#    macro avg       0.98      0.97      0.97       400
# weighted avg       0.98      0.97      0.98       400
#
# Train Score = 0.975625
# Test Score = 0.975

# %% [markdown]
# ### Suport Vector Machine¶

# %%
from sklearn.svm import SVC

# %%
svm = SVC(kernel='linear')

svm.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pre_train = svm.predict(x_train)
y_pre_train = svm.predict(x_train)

# %%
acc = accuracy_score(y_test , y_pre_test )
print(f'Accuracy = {acc}')
conf_ma = confusion_matrix(y_test,y_pre_test)
print(f"confusion matrix =\n {conf_ma}")
clas_rep = classification_report(y_test,y_pre_test)
print(f"Classification Report =\n {clas_rep}")
train_score = svm.score(x_train, y_train)
print(f"Train Score = {train_score}")
test_score = svm.score(x_test, y_test)
print(f"Test Score = {test_score}")
# Out:
# Accuracy = 0.975
# confusion matrix =
#  [[101   4   0   0]
#  [  0  91   0   0]
#  [  0   2  87   3]
#  [  0   0   1 111]]
# Classification Report =
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       105
#            1       0.94      1.00      0.97        91
#            2       0.99      0.95      0.97        92
#            3       0.97      0.99      0.98       112
#
#     accuracy                           0.97       400
#    macro avg       0.98      0.97      0.97       400
# weighted avg       0.98      0.97      0.98       400
#
# Train Score = 0.9775
# Test Score = 0.97

# %% [markdown]
# ## K-Nearest Neighbors (Distance)¶

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=100)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=100)

# %%
y_pre_train = knn.predict(x_train)
y_pre_test = knn.predict(x_test)

# %%
acc = accuracy_score(y_test , y_pre_test )
print(f'Accuracy = {acc}')
conf_ma = confusion_matrix(y_test,y_pre_test)
print(f"confusion matrix =\n {conf_ma}")
clas_rep = classification_report(y_test,y_pre_test)
print(f"Classification Report =\n {clas_rep}")
train_score = knn.score(x_train, y_train)
print(f"Train Score = {train_score}")
test_score = knn.score(x_test, y_test)
print(f"Test Score = {test_score}")
# Out:
# Accuracy = 0.6675
# confusion matrix =
#  [[80 23  2  0]
#  [16 57 18  0]
#  [ 0 25 59  8]
#  [ 0  1 40 71]]
# Classification Report =
#                precision    recall  f1-score   support
#
#            0       0.83      0.76      0.80       105
#            1       0.54      0.63      0.58        91
#            2       0.50      0.64      0.56        92
#            3       0.90      0.63      0.74       112
#
#     accuracy                           0.67       400
#    macro avg       0.69      0.67      0.67       400
# weighted avg       0.71      0.67      0.68       400
#
# Train Score = 0.691875
# Test Score = 0.6675

# %% [markdown]
# ## Decision Tree¶

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=10, random_state=42, min_samples_split=40)

dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_split=40, random_state=42)

# %%
_pre_train = dt.predict(x_train)
y_pre_test = dt.predict(x_test)

# %%
acc = accuracy_score(y_test , y_pre_test )
print(f'Accuracy = {acc}')
conf_ma = confusion_matrix(y_test,y_pre_test)
print(f"confusion matrix =\n {conf_ma}")
clas_rep = classification_report(y_test,y_pre_test)
print(f"Classification Report =\n {clas_rep}")
train_score = dt.score(x_train, y_train)
print(f"Trian Score = {train_score}")
test_score = dt.score(x_test, y_test)
print(f"Test Score = {test_score}")
# Out:
# Accuracy = 0.835
# confusion matrix =
#  [[91 14  0  0]
#  [ 4 78  9  0]
#  [ 0 14 67 11]
#  [ 0  0 14 98]]
# Classification Report =
#                precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       105
#            1       0.74      0.86      0.79        91
#            2       0.74      0.73      0.74        92
#            3       0.90      0.88      0.89       112
#
#     accuracy                           0.83       400
#    macro avg       0.83      0.83      0.83       400
# weighted avg       0.84      0.83      0.84       400
#
# Trian Score = 0.898125
# Test Score = 0.835

# %% [raw]
# I created 4 models on the data. The best model in terms of accuracy, fine-tuning, recall and F1 score was logistic regression

# %% [markdown]
# ## Hyperparameter Tuning ¶

# %% [markdown]
# ### Logistic Regression¶

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

lr = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=5000, solver='saga')
)
lr.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=5000, solver='saga'))])

# %%
LogisticRegression(max_iter=5000, solver='saga', C=10)
# Out:
# LogisticRegression(C=10, max_iter=5000, solver='saga')

# %%
LogisticRegression(max_iter=5000, solver='lbfgs')
# Out:
# LogisticRegression(max_iter=5000)

# %%
# Define model
lr = LogisticRegression(max_iter=2000)

# Define parameter grid
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga']
}

# Grid search
grid = GridSearchCV(lr, param_grid, cv=5, scoring='accuracy')
grid.fit(x_train, y_train)

print("Best parameters:", grid.best_params_)
print("Best score:", grid.best_score_)
# Out:
# C:\Users\pc\miniconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# C:\Users\pc\miniconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# C:\Users\pc\miniconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'l1_ratio': [0, 0.5, 1]  # 0=L2, 1=L1, 0.5=Elastic Net
}

lr = LogisticRegression(max_iter=2000, solver='saga')

grid = GridSearchCV(lr, param_grid, cv=5, scoring='accuracy')
grid.fit(x_train, y_train)

print("Best params:", grid.best_params_)
print("Best score:", grid.best_score_)
# Out:
# C:\Users\pc\miniconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\pc\miniconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\pc\miniconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\pc\miniconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\pc\miniconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %% [markdown]
# ### SVM

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.svm import SVC

# Define model
svm = SVC(kernel='linear')

# Define parameter grid
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'class_weight': [None, 'balanced']
}

# Stratified K-Fold for classification
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Grid search
grid = GridSearchCV(svm, param_grid, cv=skf, scoring='accuracy')
grid.fit(x_train, y_train)

print("Best parameters:", grid.best_params_)
print("Best CV score:", grid.best_score_)
# Out:
# Best parameters: {'C': 10, 'class_weight': 'balanced'}
# Best CV score: 0.9650000000000001

# %% [markdown]
# ### KNN

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier

# Define model
knn = KNeighborsClassifier()

# Define parameter grid
param_grid = {
    'n_neighbors': [3, 5, 10, 20, 50, 100],
    'weights': ['uniform', 'distance'],
    'metric': ['minkowski', 'manhattan']
}

# Stratified K-Fold for classification
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Grid search
grid = GridSearchCV(knn, param_grid, cv=skf, scoring='accuracy')
grid.fit(x_train, y_train)

print("Best parameters:", grid.best_params_)
print("Best CV score:", grid.best_score_)
# Out:
# Best parameters: {'metric': 'manhattan', 'n_neighbors': 100, 'weights': 'distance'}
# Best CV score: 0.711875

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# Define parameter grid
param_grid = {
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 10, 20, 40],
    'min_samples_leaf': [1, 5, 10],
    'criterion': ['gini', 'entropy']
}

# Initialize model
dt = DecisionTreeClassifier(random_state=42)

# Grid search with cross-validation
grid_search = GridSearchCV(dt, param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Best parameters: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# Best score: 0.8518749999999999

# %% [markdown]
# ### save the model

# %%
import pickle

# %%
output_file = f'model.bin'

# %%
output_file
# Out:
# 'model.bin'

# %%
f_out = open(output_file, 'wb') 
pickle.dump((model), f_out)
f_out.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 f_out = open(output_file, 'wb')
# ----> 2 pickle.dump((model), f_out)
#       3 f_out.close()
#
# NameError: name 'model' is not defined

# %%
# Save the model
joblib.dump(model, "model.pkl")

# Load the model later
loaded_model = joblib.load("model.pkl")
print(loaded_model.predict(X[:2]))
